# %% [markdown]
# # 1 Afficher le dossier courant
# ```bash
#
# ```
# # 2 Remonter dans le répertoire /home/vscode
# ```bash
#
# ```
# # 3 Créer un dossier miniTP dans ce repertoire
# ```bash
#
# ```
# # 4 Afficher le contenu de tous les fichiers ou dossiers présents
# ```bash
#
# ```
# # 5 Créer un fichier note.txt
# ```bash
#
# ```
# # 6 Ajouter dans ce ficher la ligne "Linux is powerful"
# ```bash
#
# ```
# # 7 Renommer ce fichier sans le déplacer en notes_backup.txt
# ```bash
#
# ```
# # 8 Copier ce fichier dans le dossier cours de voter workspace
# ```bash
#
# ```
# # 9 Compter le nombre de mots dans le fichier
# ```bash
#
# ```
# # 10 Afficher la/les lignes avec le mot powerful dans la console
# ```bash
#
# ```
